# %%
import json

import numpy as np
import pandas as pd
import os


DATA_PATH = "../dataset/samples.json"

with open(DATA_PATH, encoding="utf-8") as f:
    records = json.load(f)

df= pd.DataFrame(records)

display(df.columns)
# display(df.head(10))
display(df.info())
display(df.describe())
display(df.isnull().sum())
df["label"].value_counts()

print("null values")
display((df["context"] == "[NULL]").sum())
# Out:
# Index(['context', 'prompt_bn', 'response_bn', 'label'], dtype='str')
# <class 'pandas.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   context      297 non-null    str
#  1   prompt_bn    299 non-null    str
#  2   response_bn  299 non-null    object
#  3   label        299 non-null    int64
# dtypes: int64(1), object(1), str(2)
# memory usage: 9.5+ KB
# None
#             label
# count  299.000000
# mean     0.545151
# std      0.498792
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000
# context        2
# prompt_bn      0
# response_bn    0
# label          0
# dtype: int64
# null values
# np.int64(167)
