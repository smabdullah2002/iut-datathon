# %%
import json

import numpy as np
import pandas as pd
import os


DATA_PATH = "../dataset/samples.json"

with open(DATA_PATH, encoding="utf-8") as f:
    records = json.load(f)

df= pd.DataFrame(records)

display(df.columns)
# display(df.head(10))
display(df.info())
display(df.describe())
display(df.isnull().sum())
df["label"].value_counts()

print("null values")
display((df["context"] == "[NULL]").sum())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2599/13834534.py in <cell line: 0>()
#       8 DATA_PATH = "../dataset/samples.json"
#       9
# ---> 10 with open(DATA_PATH, encoding="utf-8") as f:
#      11     records = json.load(f)
#      12
#
# FileNotFoundError: [Errno 2] No such file or directory: '../dataset/samples.json'
